# %%
# %matplotlib inline
# %matplotlib widget # for interactive

# %% [markdown]
# # Lattice design with Xsuite
#
# For more info on lattice definition and manipulation see [Environment Section in the User's guide](https://xsuite.readthedocs.io/en/latest/environment.html)
#
# We will use as example the PIMM lattice developed by the TERA collaboration for proton and ion therapy ([CERN/PS 99-010](https://cds.cern.ch/record/385378/)) and implemented in the CNAO and MEDAUSTRON synchrotrons.

# %%
import matplotlib.pyplot as plt
import xtrack as xt
import numpy as np

# %% [markdown]
# ### Build Xsuite environment and define a reference particle

# %%
env = xt.Environment()

# %%
env.vars.default_to_zero = True # Undefined variables in env are automatically 
                                # set to zero.

# %% [markdown]
# ### Define elements

# %%
# Element geometry
n_bends = 16
env['ang_mb'] = 2 * np.pi / n_bends
env['l_mb'] = 1.65
env['l_mq'] = 0.35

env.new('mb', xt.RBend, length_straight='l_mb', angle='ang_mb')
env.new('mq', xt.Quadrupole, length='l_mq');

# %%
# Quadrupole families with different strengths
env.new('qfa', 'mq', k1= 'kqfa')
env.new('qfb', 'mq', k1= 'kqfb')
env.new('qd',  'mq', k1= 'kqd');

# %%
# Two quadrupoles of the same family
env.new('qfal', 'qfa')
env.new('qfar', 'qfa');

# %%
tt_elem = env.elements.get_table()
tt_elem
# Out:
# LineTable: 13 rows, 9 cols
# name      element_type isthick isreplica parent_name parent_type prototype iscollective ...
# mb        RBend           True     False None        None        None             False
# mq        Quadrupole      True     False None        None        None             False
# qd        Quadrupole      True     False None        None        mq               False
# qfa       Quadrupole      True     False None        None        mq               False
# qfal      Quadrupole      True     False None        None        qfa              False
# qfar      Quadrupole      True     False None        None        qfa              False
# qfb       Quadrupole      True     False None        None        mq               False
# ||drift_1 Drift           True     False None        None        None             False
# ||drift_2 Drift           True     False None        None        None             False
# ||drift_3 Drift           True     False None        None        None             False
# ||drift_4 Drift           True     False None        None        None             False
# ||drift_5 Drift           True     False None        None        None             False
# ||drift_6 Drift           True     False None        None        None             False

# %% [markdown]
# ### Build lattice cells

# %%
cell_a = env.new_line(length=7.405, components=[
    # Quadrupoles
    env.place('qfal', at=0.3875),
    env.place('qd', at=3.2925),
    env.place('qfar', at=6.3275),
    # Dipoles
    env.place('mb', at=1.425, from_='qfal@center'), # <- relative place
    env.place('mb', at=5.0475),
])

# %%
cell_a.get_table()
# Out:
# LineTable: 12 rows, 13 cols
# name                   s element_type isthick isreplica parent_name parent_type prototype ...
# ||drift_1              0 Drift           True     False None        None        None
# qfal              0.2125 Quadrupole      True     False None        None        qfa
# ||drift_2         0.5625 Drift           True     False None        None        None
# mb::0           0.982175 RBend           True     False None        None        None
# ||drift_3        2.64282 Drift           True     False None        None        None
# qd                3.1175 Quadrupole      True     False None        None        mq
# ||drift_4         3.4675 Drift           True     False None        None        None
# mb::1            4.21718 RBend           True     False None        None        None
# ||drift_5        5.87782 Drift           True     False None        None        None
# qfar              6.1525 Quadrupole      True     False None        None        qfa
# ||drift_6         6.5025 Drift           True     False None        None        None
# _end_point         7.405                False     False None        None        None

# %%
cell_a.survey().plot()

# %%
cell_b = env.new_line(length=8.405, components=[
    env.place('qfb', at=1.2725),
    env.place('mb', at= 2.7275),
    env.place('qd', at=4.8575),
    env.place('mb', at=6.5125),
    env.place('qfb', at=7.7925),
])

# %%
plt.figure(2)
cell_b.survey().plot()

# %% [markdown]
# ### Build an arc

# %%
# concatenate the two cells
arc = cell_a + cell_b

# %%
arc.survey().plot()

# %% [markdown]
# ### Build straight sections

# %%
# Empty lines with a marker in the middle
long_straight = env.new_line(length=2., components=[
    env.new('mid.lss', xt.Marker, at=1.)
])
short_straight = env.new_line(length=1., components=[
    env.new('mid.sss', xt.Marker, at=1.)
])

# %% [markdown]
# ### Assemble the ring

# %%
half_ring = (long_straight
             + arc
             + short_straight
             - arc # mirror symmetric lattice
            )

# %%
half_ring.survey().plot()

# %%
ring = 2 * half_ring

# %%
ring.survey().plot()

# %% [markdown]
# ### Replace repeated elements

# %%
ring.replace_all_repeated_elements() # give all elements unique names

# %% [markdown]
# ### Inspect beamline table
#
# Xsuite tables are used as output for many Xsuite functionalities (e.g. Twiss and Survey). They have many handy row/cols selection capabilities (see ["Working with tables" in the User's guide](https://xsuite.readthedocs.io/en/latest/tables.html)).

# %%
tt = ring.get_table()
tt.cols['element_type s_start s_center s_end']
# Out:
# LineTable: 99 rows, 5 cols
# name          element_type       s_start      s_center         s_end
# ||drift_13::0 Drift                    0           0.5             1
# mid.lss.0     Marker                   1             1             1
# ||drift_13::1 Drift                    1           1.5             2
# ||drift_1::0  Drift                    2       2.10625        2.2125
# qfal.0        Quadrupole          2.2125        2.3875        2.5625
# ||drift_2::0  Drift               2.5625       2.77234       2.98218
# mb.0          RBend              2.98218        3.8125       4.64282
# ||drift_3::0  Drift              4.64282       4.88016        5.1175
# qd.0          Quadrupole          5.1175        5.2925        5.4675
# ||drift_4::0  Drift               5.4675       5.84234       6.21718
# ...
# ||drift_5::3 Drift              63.0875       63.2248       63.3622
# mb.14        RBend              63.3622       64.1925       65.0228
# ||drift_4::3 Drift              65.0228       65.3977       65.7725
# qd.7         Quadrupole         65.7725       65.9475       66.1225
# ||drift_3::3 Drift              66.1225       66.3598       66.5972
# mb.15        RBend              66.5972       67.4275       68.2578
# ||drift_2::3 Drift              68.2578       68.4677       68.6775
# qfal.3       Quadrupole         68.6775       68.8525       69.0275
# ||drift_1::3 Drift              69.0275       69.1338         69.24
# _end_point                        69.24         69.24         69.24

# %%
# Inspect all quadrupoles
tt_quad = tt.rows.match(element_type='Quadrupole')
tt_quad.cols['s_start s_center s_end']
# Out:
# LineTable: 24 rows, 4 cols
# name         s_start      s_center         s_end
# qfal.0        2.2125        2.3875        2.5625
# qd.0          5.1175        5.2925        5.4675
# qfar.0        8.1525        8.3275        8.5025
# qfb.0        10.5025       10.6775       10.8525
# qd.1         14.0875       14.2625       14.4375
# qfb.1        17.0225       17.1975       17.3725
# qfb.2        19.2475       19.4225       19.5975
# qd.2         22.1825       22.3575       22.5325
# qfb.3        25.7675       25.9425       26.1175
# qfar.1       28.1175       28.2925       28.4675
# qd.3         31.1525       31.3275       31.5025
# qfal.1       34.0575       34.2325       34.4075
# qfal.2       36.8325       37.0075       37.1825
# qd.4         39.7375       39.9125       40.0875
# qfar.2       42.7725       42.9475       43.1225
# qfb.4        45.1225       45.2975       45.4725
# qd.5         48.7075       48.8825       49.0575
# qfb.5        51.6425       51.8175       51.9925
# qfb.6        53.8675       54.0425       54.2175
# qd.6         56.8025       56.9775       57.1525
# qfb.7        60.3875       60.5625       60.7375
# qfar.3       62.7375       62.9125       63.0875
# qd.7         65.7725       65.9475       66.1225
# qfal.3       68.6775       68.8525       69.0275

# %%
# Tag all quadrupoles in survey plot
sv = ring.survey()
sv.plot(labels=tt_quad.name);

# %% [markdown]
# ### Define and install sextupoles

# %%
# Magnet type
env.new('ms', xt.Sextupole, length=0.2)

# Magnet instances
env.new('msf.1', 'ms', k2='ksf')
env.new('msf.2', 'ms', k2='ksf')
env.new('msd.1', 'ms', k2='ksd')
env.new('msd.2', 'ms', k2='ksd')
env.new('mse',   'ms', k2='kse');

# %%
insertions = [
    env.place('msf.1', at=-0.2, from_='qfb.0@start'),
    env.place('msf.2', at=-0.2, from_='qfb.4@start'),
    env.place('msd.1', at=0.3,  from_='qd.2@end'),
    env.place('msd.2', at=0.3,  from_='qd.6@end'),
    env.place('mse',   at=-0.3, from_='qfal.2@start')
]
ring.insert(insertions) # Faster than making the insertions individually (matters for large rings)
# Out:
# Slicing line:   0%|          | 0/98 [00:00<?, ?it/s]

# %%
# Inspect sextupoles in the survey
sv = ring.survey()
sv.plot(labels=['msf.1', 'msf.2', 'msd.1', 'msd.2', 'mse'])

# %% [markdown]
# ### Inspect deferred expression

# %%
# Entities controlled by one knob
env.info('kqd')
# Out:
# Info for vars['kqd']
#
# value: 0.0
#
# Not controlled by other entities.
#
# controlled_targets:
#    element_refs['qd.7'].k1
#    element_refs['qd.6'].k1
#    element_refs['qd.5'].k1
#    element_refs['qd.4'].k1
#    element_refs['qd.3'].k1
#    element_refs['qd.2'].k1
#    element_refs['qd.1'].k1
#    element_refs['qd.0'].k1
#    element_refs['qd'].k1

# %%
# Inspect knob controlling one magnet
env.info('qd.3')
# Out:
# Element of type:  Quadrupole
# name                value                                                       expr
# k1                  0.0                                                         vars['kqd']
# k1s                 0.0                                                         None
# length              0.35                                                        vars['l_mq']
# num_multipole_kicks 0                                                           None
# order               5                                                           None
# inv_factorial_order 0.008333333333333333                                        None
# knl                 [0. 0. 0. 0. 0. 0.]                                         None
# ksl                 [0. 0. 0. 0. 0. 0.]                                         None
# knl_rel             [0.]                                                        None
# ksl_rel             [0.]                                                        None
# main_is_skew        False                                                       None
# edge_entry_active   0                                                           None
# edge_exit_active    0                                                           None
# model               adaptive                                                    None
# integrator          adaptive                                                    None
# radiation_flag      0                                                           None
# delta_taper         0.0                                                         None
# shift_x             0.0                                                         None
# shift_y             0.0                                                         None
# shift_s             0.0                                                         None
# rot_s_rad           0.0                                                         None
# rot_x_rad           0.0                                                         None
# rot_y_rad           0.0                                                         None
# rot_s_rad_no_frame  0.0                                                         None
# rot_shift_anchor    0.0                                                         None
# _tpsa_enabled       0                                                           None
# _internal_record_id RecordIdentifier(buffer_id=np.int64(0), offset=np.int64(0)) None

# %% [markdown]
# ### Install RF cavity

# %%
env.new('rf1', xt.Cavity, voltage='vrf', frequency='frf')
ring.insert('rf1', at=0.5, from_='qfal.3@start')
# Out:
# Slicing line:   0%|          | 0/107 [00:00<?, ?it/s]

# %%
sv = ring.survey()
sv.plot(labels=['rf1'])

# %% [markdown]
# ### Save lattice to json file

# %%
env
# Out:
# Environment(0 lines: {}, 86 elements, 12 vars, 0 particles)

# %%
# I put in the environment the lines I want to keep
env['ring'] = ring
env['cell_a'] = cell_a

# %%
env
# Out:
# Environment(2 lines: {ring, cell_a}, 86 elements, 12 vars, 0 particles)

# %%
env.to_json('pimm.json')
